# %%
import os
import pandas_datareader as web
import pandas as pd
import matplotlib.pyplot as plt

# %%
def clear():
    os.system('cls' if os.name == 'nt' else 'clear')

# %% [markdown]
# ### Base de dados Online:
#
# A escolha por utilizar este tipo de base é o fato de sempre pegar dados atualizados diariamente.

# %%
# df = web.DataReader('BTC-USD', data_source='yahoo', start='2017-07-14', end='2020-05-09')
df = web.DataReader('DOGE-USD', data_source='yahoo', start='2021-05-01', end='2021-05-24')
df.head()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close
# Date
# 2021-04-30  0.397135  0.328290  0.337559  0.392987  10123343703   0.392987
# 2021-05-01  0.400029  0.364874  0.391087  0.376046   8040406918   0.376046
# 2021-05-02  0.445567  0.373631  0.373631  0.441707  10526649978   0.441707
# 2021-05-03  0.605998  0.400800  0.440274  0.541334  38238126181   0.541334
# 2021-05-04  0.695262  0.523822  0.537355  0.657633  42525098292   0.657633

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12, 6))
plt.title('Doge')
plt.plot(df['Close'])
plt.xlabel('Periodo', fontsize=18)
plt.ylabel('Valor em USD($)', fontsize=18)
plt.show()
